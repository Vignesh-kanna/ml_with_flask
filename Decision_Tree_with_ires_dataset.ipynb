# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh-kanna/ml_with_flask/blob/main/Decision_Tree_with_ires_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_name = '/content/iris.csv'

# %%
import pandas as pd
iris=pd.read_csv(file_name)

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
iris.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
label_encoder = preprocessing.LabelEncoder()
iris['Species']= label_encoder.fit_transform(iris['Species'])

# %%
x=iris.iloc[:,0:4]
y=iris['Species']

# %%
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]

# %%
iris= iris.rename(columns={"Species":"Flowers_types"})

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#      Flowers_types
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...

# %%
labael_encoder = preprocessing.LabelEncoder()
iris['Flowers_types']= label_encoder.fit_transform(iris['Flowers_types'])
iris['Flowers_types']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
x=iris.iloc[:,0:4]
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]

# %%
x=iris['Flowers_types']
x
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
y=iris['Flowers_types']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
colnames = list(iris.columns)
colnames
# Out:
# ['Unnamed: 0',
#  'Sepal.Length',
#  'Sepal.Width',
#  'Petal.Length',
#  'Petal.Width',
#  'Flowers_types']

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=40)

# %%
x=iris[['Flowers_types']]
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=40)
model = DecisionTreeClassifier(criterion = 'entropy',max_depth=3)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
tree.plot_tree(model);

# %%
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa','versicolor','virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(model,
               feature_names = fn,
               class_names=cn,
               filled = True);
